# %%
dic = { "name" : "john", "age":30,"city":"New York"}
print(dic["name"])
# Out:
# john

# %%
#keys are case senstive
word={}
word["hello"]= "world"
word["Hello"]= "welcome"
print(word)
# Out:
# {'hello': 'world', 'Hello': 'welcome'}

# %%
p={"raj":1,"ram":2,"shyam":3}
print(p)
p["raj"]=4
print(p)
# Out:
# {'raj': 1, 'ram': 2, 'shyam': 3}
# {'raj': 4, 'ram': 2, 'shyam': 3}

# %%
# other vaalues thn  nummber and string
p={@:1,"ram":2,"shyam":3}
print(p)
p["raj"]=4
print(p)
# Out:
#   Cell In[13], line 1
#     p={@:1,"ram":2,"shyam":3}
#        ^
# SyntaxError: invalid syntax

# %%
#two strings , so it shows error, because set are mutable and mutable are not hasable
p={{"raj"}:1, "ram":2, "shyam":3}
print(p)
p["raj"]=4
print(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 p={{"raj"}:1,"ram":2,"shyam":3}
#       2 print(p)
#       3 p["raj"]=4
#
# TypeError: unhashable type: 'set'

# %%
#Write a program to input ‘n’ employee numbers and names and store them in a dictionary. Display dictionaries employee’s names(key) and numbers(values) together.
n = int(input("Enter number of employees: "))
employees = {}
for i in range(n):
    name = input("Enter name: ")
    num = input("Enter number: ")
    employees[name] = num
print(employees)
# Out:
# Enter number of employees:  2
# Enter name:  bhavani
# Enter number:  01
# Enter name:  bhargvai
# Enter number:  02
# {'bhavani': '01', 'bhargvai': '02'}
