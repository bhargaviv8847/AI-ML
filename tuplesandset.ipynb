# %%
my_tuple = (10,20,30,50,40)
print("tuple:",my_tuple)
# Out:
# tuple: (10, 20, 30, 50, 40)

# %%
#index
my_tuple = (10,20,30,50,40)
index_of_20 = my_tuple.index(20)
print("Index of 20:", index_of_20)
# Out:
# Index of 20: 1

# %%
#count()
my_tuple = (10,20,30,50,40,50,60,78,)
count_10 = my_tuple.count(10)
print("count of 10:", count_10)
# Out:
# count of 10: 1

# %%
#len()
my_tuple = (10, 20, 30, 40)
print(len(my_tuple))
# Out:
# 4

# %%
#max and min
my_tuple = (10, 20, 30, 50, 40, 50, 60, 78)
maximum_value = max(my_tuple)
minimum_value = min(my_tuple)
print("Maximum:", maximum_value)
print("Minimum:", minimum_value)
# Out:
# Maximum: 78
# Minimum: 10

# %%
#sum()
my_tuple = (10, 20, 30, 50, 40)
total = sum(my_tuple)
print(total)
# Out:
# 150

# %%
my_tuple = (10,20,30,50,40,50,60,78,)

# %%
#tuple() constructor The tuple() constructor converts any iterable into a tuple.

# %%
#Given a tuple of numbers and a target element, find and print all indexes where the target element occurs in the tuple.

numbers = (10, 20, 30, 20, 40, 20, 50)
target =20
indexes = []
for i in range(len(numbers)):
    if numbers[i] == target:
        indexes.append(i)
print("indexes:", indexes)
# Out:
# indexes: [1, 3, 5]

# %%
#set 
my_set = {1,2,4,4,5}
print("initial set:", my_set)
print(type(my_set))
# Out:
# initial set: {1, 2, 4, 5}
# <class 'set'>

# %%
#add
my_set = {1,2,4}
my_set.add(3)
print("after add:",my_set)
# Out:
# after add: {1, 2, 3, 4}

# %%
#update
my_set = {1,2}
my_set.update((1,2,3),[5,6,7])
print("after update:",my_set)
# Out:
# after update: {1, 2, 3, 5, 6, 7}

# %%
#remove
my_set = {1,2}
my_set.remove(2)
print("after remove:",my_set)
# Out:
# after remove: {1}

# %%
#discard( doesnt throw an error)
my_set = {1,2}
my_set.discard(4)
print("after discard:",my_set)
# Out:
# after discard: {1, 2}

# %%
#pop(removes last item)

my_set = {1,2,6}
remove_item = my_set.pop()
print("removed item:",remove_item)
print("after pop:",my_set)
# Out:
# removed item: 1
# after pop: {2, 6}

# %%
#clear

my_set = {10, 20, 30, 40}
my_set.clear()
print("After clear():", my_set)
# Out:
# After clear(): set()

# %%
#union
set1 = {1,2,3}
set2 = {3,4,5}
result = set1.union(set2)
print("union:",result)
# Out:
# union: {1, 2, 3, 4, 5}

# %%
#intersection
set1 = {1,2,3}
set2 = {3,2,5}
result = set1.intersection(set2)
print("intersection:",result)
# Out:
# union: {2, 3}

# %%
#symmetric difference (set1)
set1 = {1,2,3}
set2 = {3,2,4}
result = set1.symmetric_difference(set2)
print("symmetric:", result)
# Out:
# symmetric: {1, 4}

# %%
#difference
set1 = {1,2,3}
set2 = {3,2,4}
result = set1.difference(set2)
print("symmetric:", result)
# Out:
# symmetric: {1}

# %%
#isssubset
set1 = {1,2}
set2 = {1,2,4}
print("Is set1 subset of set2?",set1.issubset(set2))
# Out:
# Is set1 subset of set2? True

# %%
#issuperset
set1 = {1,2,4}
set2 = {1,2}
print("Is set1 superset of set2?",set1.issuperset(set2))
# Out:
# Is set1 superset of set2? True

# %%
#remove duplicates from a list using set
numbers = [1, 2, 3, 2, 4, 1, 5]
my_set = set()
my_set.update(numbers)
result = list(my_set)

print("after removing duplicates:", result)
# Out:
# after removing duplicates: [1, 2, 3, 4, 5]
